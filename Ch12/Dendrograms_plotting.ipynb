# %% [markdown]
# # Dendrogram Plotting

# %%
import random
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.cluster.hierarchy as shc
from scipy.spatial.distance import squareform, pdist

# %matplotlib inline

# %% [markdown]
# ## Random dataset

# %%
a = np.random.random_sample(size = 10)
b = np.random.random_sample(size = 10)
point = ['P1','P2','P3','P4','P5','P6','P7','P8','P9','P10']
data = pd.DataFrame({'Point':point, 'a':np.round(a,2), 'b':np.round(b,2)})
data = data.set_index('Point')

# %%
data
# Out:
#           a     b
# Point
# P1     0.22  0.39
# P2     0.85  0.06
# P3     0.27  0.42
# P4     0.92  0.74
# P5     0.29  0.88
# P6     0.56  0.59
# P7     0.34  0.43
# P8     0.31  0.73
# P9     0.86  0.85
# P10    0.93  0.35

# %% [markdown]
# ## Data distribution

# %%
 plt.style.use(['ggplot'])
plt.figure(figsize=(8,5))
plt.scatter(data['a'], data['b'], c='r', marker='*')
plt.xlabel('Column a')
plt.ylabel('column b')
plt.title('Scatter Plot of x and y')
# Out:
# Text(0.5, 1.0, 'Scatter Plot of x and y')

# %%
dist = pd.DataFrame(squareform(pdist(data[['a', 'b']]), 'euclidean'), columns=data.index.values, index=data.index.values)

# %%
dist
# Out:
#            P1        P2        P3  ...        P8        P9       P10
# P1   0.000000  0.711196  0.058310  ...  0.351710  0.788162  0.711126
# P2   0.711196  0.000000  0.682642  ...  0.860523  0.790063  0.300832
# P3   0.058310  0.682642  0.000000  ...  0.312570  0.730068  0.663702
# P4   0.782624  0.683593  0.724500  ...  0.610082  0.125300  0.390128
# P5   0.494975  0.992975  0.460435  ...  0.151327  0.570789  0.830963
# P6   0.394462  0.604152  0.336155  ...  0.286531  0.396989  0.441022
# P7   0.126491  0.630079  0.070711  ...  0.301496  0.668431  0.595399
# P8   0.351710  0.860523  0.312570  ...  0.000000  0.562939  0.727186
# P9   0.788162  0.790063  0.730068  ...  0.562939  0.000000  0.504876
# P10  0.711126  0.300832  0.663702  ...  0.727186  0.504876  0.000000
#
# [10 rows x 10 columns]

# %% [markdown]
# ## Single linkage

# %%
plt.title("Single Linkage")  
dend = shc.dendrogram(shc.linkage(data[['a', 'b']], method='single'), labels=data.index)

# %% [markdown]
# ## Complete linkage

# %%
plt.title("Complete linkage")  
dend = shc.dendrogram(shc.linkage(data[['a', 'b']], method='complete'), labels=data.index)

# %% [markdown]
# ## Average linkage

# %%
plt.title("Average linkage")  
dend = shc.dendrogram(shc.linkage(data[['a', 'b']], method='average'), labels=data.index)
